# %%
import pandas as pd
import requests
import pymongo
import requests

# %%
# Read the GDP per capita data from wikipedia
tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28PPP%29_per_capita')

# %%
# get exact data from table
gdp_per_capita = tables[2]

# %%
# clean data and rename the columns 
gdp_per_capita_df = gdp_per_capita.loc[gdp_per_capita.loc[:,'Rank']!= '—']
gdp_per_capita_df.columns = ['rank', 'country', 'gdp_per_capita']
gdp_per_capita_df = gdp_per_capita_df.iloc[:,1:3]
gdp_per_capita_clean_df = gdp_per_capita_df.reset_index(drop=True)
gdp_per_capita_clean_df.head()
# Out:
#       country  gdp_per_capita
# 0       Qatar        138910.0
# 1  Luxembourg        112045.0
# 2   Singapore        105689.0
# 3     Ireland         86988.0
# 4      Brunei         85011.0

# %%
# Read the population from wikipedia
tables = pd.read_html('https://worldpopulationreview.com/countries')
tables[0]
# Out:
#      Rank           Country  2020 Population  2019 Population Growth Rate  \
# 0       1             China       1439323776       1433783686       0.39%
# 1       2             India       1380004385       1366417754       0.99%
# 2       3     United States        331002651        329064917       0.59%
# 3       4         Indonesia        273523615        270625568       1.07%
# 4       5          Pakistan        220892340        216565318       2.00%
# ..    ...               ...              ...              ...         ...
# 227   228        Montserrat             4992             4989       0.06%
# 228   229  Falkland Islands             3480             3377       3.05%
# 229   230              Niue             1626             1615       0.68%
# 230   231           Tokelau             1357             1340       1.27%
# 231   232      Vatican City              801              799       0.25%
#
#      Area (km²) 2018 Density
# 0       9706961      148/km²
# 1       3287590      416/km²
# 2       9372610       35/km²
# 3       1904569      142/km²
# 4        881912      246/km²
# ..          ...          ...
# 227         102       49/km²
# 228       12173        0/km²
# 229         260        6/km²
# 230          12      112/km²
# 231           1      799/km²
#
# [232 rows x 7 columns]

# %%
# get exact data from table
country_population_df = tables[0]
# clean data and rename the columns 
country_population_df.columns = ['rank', 'country', 'population', 'population2', 'growthrate', 'countrysize', 'pop_den']
country_population_clean_df = country_population_df.loc[:,['country', 'population', 'growthrate', 'countrysize', 'pop_den']]
country_population_clean_df.loc[:,'pop_den']= country_population_clean_df.loc[:,'pop_den'].str[:-4]
country_population_clean_df.loc[:,'growthrate'] = country_population_clean_df.loc[:,'growthrate'].str[:-1]
country_population_clean_df.loc[:,'growthrate']=country_population_clean_df.loc[:,'growthrate'].astype(float)/100
country_population_clean_df['pop_den'] = country_population_clean_df['pop_den'].str.replace(',','')
country_population_clean_df.loc[:,'pop_den']=country_population_clean_df.loc[:,'pop_den'].astype(int)
country_population_clean_df
# Out:
#               country  population  growthrate  countrysize  pop_den
# 0               China  1439323776      0.0039      9706961      148
# 1               India  1380004385      0.0099      3287590      416
# 2       United States   331002651      0.0059      9372610       35
# 3           Indonesia   273523615      0.0107      1904569      142
# 4            Pakistan   220892340      0.0200       881912      246
# ..                ...         ...         ...          ...      ...
# 227        Montserrat        4992      0.0006          102       49
# 228  Falkland Islands        3480      0.0305        12173        0
# 229              Niue        1626      0.0068          260        6
# 230           Tokelau        1357      0.0127           12      112
# 231      Vatican City         801      0.0025            1      799
#
# [232 rows x 5 columns]

# %%
# Out:
#    country  population  growthrate  countrysize  pop_den
# 21  France    65273511      0.0022       551695      118

# %%
# Read the Happiness data from wikipedia
tables = pd.read_html('https://en.wikipedia.org/wiki/World_Happiness_Report#2019_World_Happiness_Report')

# %%
# get exact data from table
country_happiest_df = tables[4]
# clean data and rename the columns 
country_happiest_df = country_happiest.loc[:, ['Country or region','Score']]
country_happiest_df.columns = ['country', 'happiestScore']
country_happiest_df.loc[country_happiest_df.loc[:, "country"] == 'United States of America']
country_happiest_df.iloc[18,0] = 'United States'

# %%
# Out:
# Empty DataFrame
# Columns: [country, co2_emissions]
# Index: []

# %%
# merging three dataframes 
populcation_data = pd.merge(gdp_per_capita_clean_df, country_population_clean_df, 
             how="left", 
             on = ["country","country"])
populcation_data = pd.merge(populcation_data, country_happiest_df, 
             how="left", 
             on = ["country","country"])
populcation_data.head()
# Out:
#       country  gdp_per_capita  co2_emissions  population  growthrate  \
# 0       Qatar        138910.0         97.787   2881053.0      0.0173
# 1  Luxembourg        112045.0          9.540    625978.0      0.0166
# 2   Singapore        105689.0         55.018   5850342.0      0.0079
# 3     Ireland         86988.0         38.914   4937786.0      0.0113
# 4      Brunei         85011.0          6.711    437479.0      0.0097
#
#    countrysize  pop_den  happiestScore
# 0      11586.0    244.0          6.374
# 1       2586.0    238.0          7.090
# 2        710.0   8175.0          6.262
# 3      70273.0     69.0          7.021
# 4       5765.0     75.0            NaN

# %%
# drop empty field 
populcation_data = populcation_data.dropna()

# %%
# create json list
populcation_data_list = [];
for index, row in populcation_data.iterrows():
    populcation_dict = {
        "country":row["country"],
        "gdp_per_capita":row["gdp_per_capita"],
        "co2_emissions":row["co2_emissions"],
        "population":row["population"],
        "growthrate":row["growthrate"],
        "countrysize":row["countrysize"],
        "pop_den":row["pop_den"],
        "happiestScore":row["happiestScore"]
    }
    populcation_data_list.append(populcation_dict)
    
populcation_data_list
# Out:
# [{'country': 'Qatar',
#   'gdp_per_capita': 138910.0,
#   'co2_emissions': 97.787,
#   'population': 2881053.0,
#   'growthrate': 0.0173,
#   'countrysize': 11586.0,
#   'pop_den': 244.0,
#   'happiestScore': 6.374},
#  {'country': 'Luxembourg',
#   'gdp_per_capita': 112045.0,
#   'co2_emissions': 9.54,
#   'population': 625978.0,
#   'growthrate': 0.0166,
#   'countrysize': 2586.0,
#   'pop_den': 238.0,
#   'happiestScore': 7.09},
#  {'country': 'Singapore',
#   'gdp_per_capita': 105689.0,
#   'co2_emissions': 55.018,
#   'population': 5850342.0,
#   'growthrate': 0.0079,
#   'countrysize': 710.0,
#   'pop_den': 8175.0,
#   'happiestScore': 6.2620000000000005},
#  {'country': 'Ireland',
#   'gdp_per_capita': 86988.0,
#   'co2_emissions': 38.914,
#   'population': 4937786.0,
#   'growthrate': 0.0113,
#   'countrysize': 70273.0,
#   'pop_den': 69.0,
#   'happiestScore': 7.021},
#  {'country': 'Norway',
#   'gdp_per_capita': 79638.0,
#   'co2_emissions': 52.492,
#   'population': 5421241.0,
#   'growthrate': 0.0079,
#   'countrysize': 323802.0,
#   'pop_den': 17.0,
#   'happiestScore': 7.553999999999999},
#  {'country': 'United Arab Emirates',
#   'gdp_per_capita': 70441.0,
#   'co2_emissions': 202.80200000000002,
#   'population': 9890402.0,
#   'growthrate': 0.0123,
#   'countrysize': 83600.0,
#   'pop_den': 117.0,
#   'happiestScore': 6.825},
#  {'country': 'Kuwait',
#   'gdp_per_capita': 67891.0,
#   'co2_emissions': 97.15100000000001,
#   'population': 4270571.0,
#   'growthrate': 0.0151,
#   'countrysize': 17818.0,
#   'pop_den': 236.0,
#   'happiestScore': 6.011},
#  {'country': 'United States',
#   'gdp_per_capita': 67426.0,
#   'co2_emissions': 5107.393,
#   'population': 331002651.0,
#   'growthrate': 0.0059,
#   'countrysize': 9372610.0,
#   'pop_den': 35.0,
#   'happiestScore': 6.892},
#  {'country': 'Netherlands',
#   'gdp_per_capita': 60299.0,
#   'co2_emissions': 174.77,
#   'population': 17134872.0,
#   'growthrate': 0.0022,
#   'countrysize': 41850.0,
#   'pop_den': 409.0,
#   'happiestScore': 7.4879999999999995},
#  {'country': 'Iceland',
#   'gdp_per_capita': 56974.0,
#   'co2_emissions': 4.0969999999999995,
#   'population': 341243.0,
#   'growthrate': 0.006500000000000001,
#   'countrysize': 103000.0,
#   'pop_den': 3.0,
#   'happiestScore': 7.494},
#  {'country': 'Saudi Arabia',
#   'gdp_per_capita': 56912.0,
#   'co2_emissions': 638.762,
#   'population': 34813871.0,
#   'growthrate': 0.0159,
#   'countrysize': 2149690.0,
#   'pop_den': 16.0,
#   'happiestScore': 6.375},
#  {'country': 'Sweden',
#   'gdp_per_capita': 55989.0,
#   'co2_emissions': 50.873999999999995,
#   'population': 10099265.0,
#   'growthrate': 0.0063,
#   'countrysize': 450295.0,
#   'pop_den': 22.0,
#   'happiestScore': 7.343},
#  {'country': 'Denmark',
#   'gdp_per_capita': 55675.0,
#   'co2_emissions': 33.573,
#   'population': 5792202.0,
#   'growthrate': 0.0034999999999999996,
#   'countrysize': 43094.0,
#   'pop_den': 134.0,
#   'happiestScore': 7.6},
#  {'country': 'Germany',
#   'gdp_per_capita': 55306.0,
#   'co2_emissions': 796.529,
#   'population': 83783942.0,
#   'growthrate': 0.0032,
#   'countrysize': 357114.0,
#   'pop_den': 234.0,
#   'happiestScore': 6.985},
#  {'country': 'Austria',
#   'gdp_per_capita': 55171.0,
#   'co2_emissions': 72.249,
#   'population': 9006398.0,
#   'growthrate': 0.005699999999999999,
#   'countrysize': 83871.0,
#   'pop_den': 107.0,
#   'happiestScore': 7.246},
#  {'country': 'Australia',
#   'gdp_per_capita': 54799.0,
#   'co2_emissions': 402.25300000000004,
#   'population': 25499884.0,
#   'growthrate': 0.0118,
#   'countrysize': 7692024.0,
#   'pop_den': 3.0,
#   'happiestScore': 7.228},
#  {'country': 'Canada',
#   'gdp_per_capita': 52144.0,
#   'co2_emissions': 617.3009999999999,
#   'population': 37742154.0,
#   'growthrate': 0.0089,
#   'countrysize': 9984670.0,
#   'pop_den': 4.0,
#   'happiestScore': 7.278},
#  {'country': 'Bahrain',
#   'gdp_per_capita': 51991.0,
#   'co2_emissions': 35.775,
#   'population': 1701575.0,
#   'growthrate': 0.0368,
#   'countrysize': 765.0,
#   'pop_den': 2145.0,
#   'happiestScore': 6.199},
#  {'country': 'Belgium',
#   'gdp_per_capita': 50904.0,
#   'co2_emissions': 104.221,
#   'population': 11589623.0,
#   'growthrate': 0.0044,
#   'countrysize': 30528.0,
#   'pop_den': 378.0,
#   'happiestScore': 6.922999999999999},
#  {'country': 'Malta',
#   'gdp_per_capita': 49589.0,
#   'co2_emissions': 1.876,
#   'population': 441543.0,
#   'growthrate': 0.0027,
#   'countrysize': 316.0,
#   'pop_den': 1394.0,
#   'happiestScore': 6.726},
#  {'country': 'Finland',
#   'gdp_per_capita': 49548.0,
#   'co2_emissions': 46.846000000000004,
#   'population': 5540720.0,
#   'growthrate': 0.0015,
#   'countrysize': 338424.0,
#   'pop_den': 16.0,
#   'happiestScore': 7.769},
#  {'country': 'United Kingdom',
#   'gdp_per_capita': 48169.0,
#   'co2_emissions': 379.15,
#   'population': 67886011.0,
#   'growthrate': 0.0053,
#   'countrysize': 242900.0,
#   'pop_den': 278.0,
#   'happiestScore': 7.053999999999999},
#  {'country': 'Japan',
#   'gdp_per_capita': 46827.0,
#   'co2_emissions': 1320.776,
#   'population': 126476461.0,
#   'growthrate': -0.003,
#   'countrysize': 377930.0,
#   'pop_den': 336.0,
#   'happiestScore': 5.886},
#  {'country': 'Cyprus',
#   'gdp_per_capita': 42956.0,
#   'co2_emissions': 7.035,
#   'population': 1207359.0,
#   'growthrate': 0.0073,
#   'countrysize': 9251.0,
#   'pop_den': 130.0,
#   'happiestScore': 6.046},
#  {'country': 'New Zealand',
#   'gdp_per_capita': 42045.0,
#   'co2_emissions': 36.795,
#   'population': 4822233.0,
#   'growthrate': 0.008199999999999999,
#   'countrysize': 270467.0,
#   'pop_den': 18.0,
#   'happiestScore': 7.307},
#  {'country': 'Czech Republic',
#   'gdp_per_capita': 40585.0,
#   'co2_emissions': 109.756,
#   'population': 10708981.0,
#   'growthrate': 0.0018,
#   'countrysize': 78865.0,
#   'pop_den': 136.0,
#   'happiestScore': 6.852},
#  {'country': 'Slovenia',
#   'gdp_per_capita': 40344.0,
#   'co2_emissions': 15.209000000000001,
#   'population': 2078938.0,
#   'growthrate': 0.0001,
#   'countrysize': 20273.0,
#   'pop_den': 103.0,
#   'happiestScore': 6.117999999999999},
#  {'country': 'Israel',
#   'gdp_per_capita': 40337.0,
#   'co2_emissions': 66.916,
#   'population': 8655535.0,
#   'growthrate': 0.016,
#   'countrysize': 20770.0,
#   'pop_den': 410.0,
#   'happiestScore': 7.138999999999999},
#  {'country': 'Lithuania',
#   'gdp_per_capita': 38751.0,
#   'co2_emissions': 15.311,
#   'population': 2722289.0,
#   'growthrate': -0.013500000000000002,
#   'countrysize': 65300.0,
#   'pop_den': 42.0,
#   'happiestScore': 6.149},
#  {'country': 'Slovakia',
#   'gdp_per_capita': 38321.0,
#   'co2_emissions': 37.855,
#   'population': 5459642.0,
#   'growthrate': 0.0005,
#   'countrysize': 49037.0,
#   'pop_den': 111.0,
#   'happiestScore': 6.1979999999999995},
#  {'country': 'Estonia',
#   'gdp_per_capita': 37606.0,
#   'co2_emissions': 17.89,
#   'population': 1326535.0,
#   'growthrate': 0.0007000000000000001,
#   'countrysize': 45227.0,
#   'pop_den': 29.0,
#   'happiestScore': 5.893},
#  {'country': 'Hungary',
#   'gdp_per_capita': 35941.0,
#   'co2_emissions': 50.856,
#   'population': 9660351.0,
#   'growthrate': -0.0025,
#   'countrysize': 93028.0,
#   'pop_den': 104.0,
#   'happiestScore': 5.757999999999999},
#  {'country': 'Poland',
#   'gdp_per_capita': 35651.0,
#   'co2_emissions': 319.028,
#   'population': 37846611.0,
#   'growthrate': -0.0011,
#   'countrysize': 312679.0,
#   'pop_den': 121.0,
#   'happiestScore': 6.182},
#  {'country': 'Portugal',
#   'gdp_per_capita': 34936.0,
#   'co2_emissions': 56.771,
#   'population': 10196709.0,
#   'growthrate': -0.0029,
#   'countrysize': 92090.0,
#   'pop_den': 111.0,
#   'happiestScore': 5.693},
#  {'country': 'Malaysia',
#   'gdp_per_capita': 34567.0,
#   'co2_emissions': 258.783,
#   'population': 32365999.0,
#   'growthrate': 0.013000000000000001,
#   'countrysize': 330803.0,
#   'pop_den': 97.0,
#   'happiestScore': 5.3389999999999995},
#  {'country': 'Latvia',
#   'gdp_per_capita': 32987.0,
#   'co2_emissions': 8.049,
#   'population': 1886198.0,
#   'growthrate': -0.0108,
#   'countrysize': 64559.0,
#   'pop_den': 30.0,
#   'happiestScore': 5.94},
#  {'country': 'Greece',
#   'gdp_per_capita': 31616.0,
#   'co2_emissions': 72.145,
#   'population': 10423054.0,
#   'growthrate': -0.0048,
#   'countrysize': 131990.0,
#   'pop_den': 79.0,
#   'happiestScore': 5.287000000000001},
#  {'country': 'Russia',
#   'gdp_per_capita': 30820.0,
#   'co2_emissions': 1764.866,
#   'population': 145934462.0,
#   'growthrate': 0.0004,
#   'countrysize': 17098242.0,
#   'pop_den': 9.0,
#   'happiestScore': 5.648},
#  {'country': 'Kazakhstan',
#   'gdp_per_capita': 30178.0,
#   'co2_emissions': 266.207,
#   'population': 18776707.0,
#   'growthrate': 0.0121,
#   'countrysize': 2724900.0,
#   'pop_den': 7.0,
#   'happiestScore': 5.809},
#  {'country': 'Romania',
#   'gdp_per_capita': 29555.0,
#   'co2_emissions': 81.131,
#   'population': 19237691.0,
#   'growthrate': -0.0066,
#   'countrysize': 238391.0,
#   'pop_den': 81.0,
#   'happiestScore': 6.07},
#  {'country': 'Turkey',
#   'gdp_per_capita': 29327.0,
#   'co2_emissions': 429.56300000000005,
#   'population': 84339067.0,
#   'growthrate': 0.0109,
#   'countrysize': 783562.0,
#   'pop_den': 106.0,
#   'happiestScore': 5.372999999999999},
#  {'country': 'Croatia',
#   'gdp_per_capita': 29207.0,
#   'co2_emissions': 17.465999999999998,
#   'population': 4105267.0,
#   'growthrate': -0.0060999999999999995,
#   'countrysize': 56594.0,
#   'pop_den': 73.0,
#   'happiestScore': 5.432},
#  {'country': 'Panama',
#   'gdp_per_capita': 28456.0,
#   'co2_emissions': 12.255999999999998,
#   'population': 4314767.0,
#   'growthrate': 0.0161,
#   'countrysize': 75417.0,
#   'pop_den': 56.0,
#   'happiestScore': 6.321000000000001},
#  {'country': 'Chile',
#   'gdp_per_capita': 27150.0,
#   'co2_emissions': 90.325,
#   'population': 19116201.0,
#   'growthrate': 0.0087,
#   'countrysize': 756102.0,
#   'pop_den': 25.0,
#   'happiestScore': 6.444},
#  {'country': 'Mauritius',
#   'gdp_per_capita': 26461.0,
#   'co2_emissions': 3.9930000000000003,
#   'population': 1271768.0,
#   'growthrate': 0.0017000000000000001,
#   'countrysize': 2040.0,
#   'pop_den': 622.0,
#   'happiestScore': 5.888},
#  {'country': 'Bulgaria',
#   'gdp_per_capita': 26034.0,
#   'co2_emissions': 49.568000000000005,
#   'population': 6948445.0,
#   'growthrate': -0.0074,
#   'countrysize': 110879.0,
#   'pop_den': 63.0,
#   'happiestScore': 5.011},
#  {'country': 'Uruguay',
#   'gdp_per_capita': 24516.0,
#   'co2_emissions': 6.93,
#   'population': 3473730.0,
#   'growthrate': 0.0034999999999999996,
#   'countrysize': 181034.0,
#   'pop_den': 19.0,
#   'happiestScore': 6.292999999999999},
#  {'country': 'Turkmenistan',
#   'gdp_per_capita': 21855.0,
#   'co2_emissions': 72.47399999999999,
#   'population': 6031200.0,
#   'growthrate': 0.015,
#   'countrysize': 488100.0,
#   'pop_den': 12.0,
#   'happiestScore': 5.247000000000001},
#  {'country': 'Mexico',
#   'gdp_per_capita': 21363.0,
#   'co2_emissions': 507.18300000000005,
#   'population': 128932753.0,
#   'growthrate': 0.0106,
#   'countrysize': 1964375.0,
#   'pop_den': 65.0,
#   'happiestScore': 6.595},
#  {'country': 'Thailand',
#   'gdp_per_capita': 21361.0,
#   'co2_emissions': 279.296,
#   'population': 69799978.0,
#   'growthrate': 0.0025,
#   'countrysize': 513120.0,
#   'pop_den': 136.0,
#   'happiestScore': 6.007999999999999},
#  {'country': 'Belarus',
#   'gdp_per_capita': 21224.0,
#   'co2_emissions': 62.34,
#   'population': 9449323.0,
#   'growthrate': -0.0003,
#   'countrysize': 207600.0,
#   'pop_den': 46.0,
#   'happiestScore': 5.3229999999999995},
#  {'country': 'China',
#   'gdp_per_capita': 20984.0,
#   'co2_emissions': 10877.218,
#   'population': 1439323776.0,
#   'growthrate': 0.0039000000000000003,
#   'countrysize': 9706961.0,
#   'pop_den': 148.0,
#   'happiestScore': 5.191},
#  {'country': 'Dominican Republic',
#   'gdp_per_capita': 20625.0,
#   'co2_emissions': 23.111,
#   'population': 10847910.0,
#   'growthrate': 0.0101,
#   'countrysize': 48671.0,
#   'pop_den': 221.0,
#   'happiestScore': 5.425},
#  {'country': 'Argentina',
#   'gdp_per_capita': 19971.0,
#   'co2_emissions': 209.968,
#   'population': 45195774.0,
#   'growthrate': 0.009300000000000001,
#   'countrysize': 2780400.0,
#   'pop_den': 16.0,
#   'happiestScore': 6.086},
#  {'country': 'Gabon',
#   'gdp_per_capita': 19839.0,
#   'co2_emissions': 6.564,
#   'population': 2225734.0,
#   'growthrate': 0.0245,
#   'countrysize': 267668.0,
#   'pop_den': 8.0,
#   'happiestScore': 4.7989999999999995},
#  {'country': 'Botswana',
#   'gdp_per_capita': 19388.0,
#   'co2_emissions': 7.912999999999999,
#   'population': 2351627.0,
#   'growthrate': 0.0208,
#   'countrysize': 582000.0,
#   'pop_den': 4.0,
#   'happiestScore': 3.488},
#  {'country': 'Azerbaijan',
#   'gdp_per_capita': 19156.0,
#   'co2_emissions': 32.544000000000004,
#   'population': 10139177.0,
#   'growthrate': 0.0091,
#   'countrysize': 86600.0,
#   'pop_den': 116.0,
#   'happiestScore': 5.207999999999999},
#  {'country': 'Iraq',
#   'gdp_per_capita': 18755.0,
#   'co2_emissions': 199.296,
#   'population': 40222493.0,
#   'growthrate': 0.0232,
#   'countrysize': 438317.0,
#   'pop_den': 90.0,
#   'happiestScore': 4.437},
#  {'country': 'Costa Rica',
#   'gdp_per_capita': 18651.0,
#   'co2_emissions': 8.138,
#   'population': 5094118.0,
#   'growthrate': 0.0092,
#   'countrysize': 51100.0,
#   'pop_den': 99.0,
#   'happiestScore': 7.167000000000001},
#  {'country': 'Iran',
#   'gdp_per_capita': 17832.0,
#   'co2_emissions': 671.45,
#   'population': 83992949.0,
#   'growthrate': 0.013000000000000001,
#   'countrysize': 1648195.0,
#   'pop_den': 50.0,
#   'happiestScore': 4.548},
#  {'country': 'Brazil',
#   'gdp_per_capita': 17106.0,
#   'co2_emissions': 492.791,
#   'population': 212559417.0,
#   'growthrate': 0.0072,
#   'countrysize': 8515767.0,
#   'pop_den': 25.0,
#   'happiestScore': 6.3},
#  {'country': 'Colombia',
#   'gdp_per_capita': 16265.0,
#   'co2_emissions': 74.954,
#   'population': 50882891.0,
#   'growthrate': 0.0108,
#   'countrysize': 1141748.0,
#   'pop_den': 44.0,
#   'happiestScore': 6.125},
#  {'country': 'Algeria',
#   'gdp_per_capita': 16091.0,
#   'co2_emissions': 159.929,
#   'population': 43851044.0,
#   'growthrate': 0.018500000000000003,
#   'countrysize': 2381741.0,
#   'pop_den': 18.0,
#   'happiestScore': 5.211},
#  {'country': 'Lebanon',
#   'gdp_per_capita': 15599.0,
#   'co2_emissions': 23.101999999999997,
#   'population': 6825445.0,
#   'growthrate': -0.0044,
#   'countrysize': 10452.0,
#   'pop_den': 656.0,
#   'happiestScore': 5.197},
#  {'country': 'Peru',
#   'gdp_per_capita': 15399.0,
#   'co2_emissions': 55.931000000000004,
#   'population': 32971854.0,
#   'growthrate': 0.014199999999999999,
#   'countrysize': 1285216.0,
#   'pop_den': 25.0,
#   'happiestScore': 5.697},
#  {'country': 'Mongolia',
#   'gdp_per_capita': 15089.0,
#   'co2_emissions': 25.747,
#   'population': 3278290.0,
#   'growthrate': 0.0165,
#   'countrysize': 1564110.0,
#   'pop_den': 2.0,
#   'happiestScore': 5.285},
#  {'country': 'Albania',
#   'gdp_per_capita': 14866.0,
#   'co2_emissions': 5.026,
#   'population': 2877797.0,
#   'growthrate': -0.0011,
#   'countrysize': 28748.0,
#   'pop_den': 100.0,
#   'happiestScore': 4.718999999999999},
#  {'country': 'Indonesia',
#   'gdp_per_capita': 14841.0,
#   'co2_emissions': 511.327,
#   'population': 273523615.0,
#   'growthrate': 0.010700000000000001,
#   'countrysize': 1904569.0,
#   'pop_den': 142.0,
#   'happiestScore': 5.192},
#  {'country': 'Egypt',
#   'gdp_per_capita': 14800.0,
#   'co2_emissions': 258.668,
#   'population': 102334404.0,
#   'growthrate': 0.0194,
#   'countrysize': 1002450.0,
#   'pop_den': 100.0,
#   'happiestScore': 4.166},
#  {'country': 'Sri Lanka',
#   'gdp_per_capita': 14509.0,
#   'co2_emissions': 23.978,
#   'population': 21413249.0,
#   'growthrate': 0.0042,
#   'countrysize': 65610.0,
#   'pop_den': 325.0,
#   'happiestScore': 4.3660000000000005},
#  {'country': 'South Africa',
#   'gdp_per_capita': 13965.0,
#   'co2_emissions': 467.654,
#   'population': 59308690.0,
#   'growthrate': 0.0128,
#   'countrysize': 1221037.0,
#   'pop_den': 48.0,
#   'happiestScore': 4.7219999999999995},
#  {'country': 'Paraguay',
#   'gdp_per_capita': 13213.0,
#   'co2_emissions': 6.535,
#   'population': 7132538.0,
#   'growthrate': 0.0125,
#   'countrysize': 406752.0,
#   'pop_den': 17.0,
#   'happiestScore': 5.742999999999999},
#  {'country': 'Georgia',
#   'gdp_per_capita': 13200.0,
#   'co2_emissions': 11.558,
#   'population': 3989167.0,
#   'growthrate': -0.0019,
#   'countrysize': 69700.0,
#   'pop_den': 57.0,
#   'happiestScore': 4.519},
#  {'country': 'Tunisia',
#   'gdp_per_capita': 13093.0,
#   'co2_emissions': 31.63,
#   'population': 11818619.0,
#   'growthrate': 0.0106,
#   'countrysize': 163610.0,
#   'pop_den': 71.0,
#   'happiestScore': 4.461},
#  {'country': 'Ecuador',
#   'gdp_per_capita': 11866.0,
#   'co2_emissions': 39.507,
#   'population': 17643054.0,
#   'growthrate': 0.0155,
#   'countrysize': 276841.0,
#   'pop_den': 63.0,
#   'happiestScore': 6.028},
#  {'country': 'Armenia',
#   'gdp_per_capita': 11845.0,
#   'co2_emissions': 4.832,
#   'population': 2963243.0,
#   'growthrate': 0.0019,
#   'countrysize': 29743.0,
#   'pop_den': 99.0,
#   'happiestScore': 4.559},
#  {'country': 'Namibia',
#   'gdp_per_capita': 11451.0,
#   'co2_emissions': 4.2989999999999995,
#   'population': 2540905.0,
#   'growthrate': 0.018600000000000002,
#   'countrysize': 825615.0,
#   'pop_den': 3.0,
#   'happiestScore': 4.638999999999999},
#  {'country': 'Bhutan',
#   'gdp_per_capita': 10627.0,
#   'co2_emissions': 1.454,
#   'population': 771608.0,
#   'growthrate': 0.011200000000000002,
#   'countrysize': 38394.0,
#   'pop_den': 20.0,
#   'happiestScore': 5.082},
#  {'country': 'Ukraine',
#   'gdp_per_capita': 10130.0,
#   'co2_emissions': 205.72299999999998,
#   'population': 43733762.0,
#   'growthrate': -0.0059,
#   'countrysize': 603500.0,
#   'pop_den': 73.0,
#   'happiestScore': 4.332},
#  {'country': 'Philippines',
#   'gdp_per_capita': 10094.0,
#   'co2_emissions': 137.154,
#   'population': 109581078.0,
#   'growthrate': 0.013500000000000002,
#   'countrysize': 342353.0,
#   'pop_den': 316.0,
#   'happiestScore': 5.631},
#  {'country': 'Jordan',
#   'gdp_per_capita': 9939.0,
#   'co2_emissions': 24.565,
#   'population': 10203134.0,
#   'growthrate': 0.01,
#   'countrysize': 89342.0,
#   'pop_den': 113.0,
#   'happiestScore': 4.906000000000001},
#  {'country': 'Jamaica',
#   'gdp_per_capita': 9932.0,
#   'co2_emissions': 7.546,
#   'population': 2961167.0,
#   'growthrate': 0.0044,
#   'countrysize': 10991.0,
#   'pop_den': 268.0,
#   'happiestScore': 5.89},
#  {'country': 'Morocco',
#   'gdp_per_capita': 9667.0,
#   'co2_emissions': 61.583999999999996,
#   'population': 36910560.0,
#   'growthrate': 0.012,
#   'countrysize': 446550.0,
#   'pop_den': 82.0,
#   'happiestScore': 5.207999999999999},
#  {'country': 'Uzbekistan',
#   'gdp_per_capita': 9595.0,
#   'co2_emissions': 95.35,
#   'population': 33469203.0,
#   'growthrate': 0.0148,
#   'countrysize': 447400.0,
#   'pop_den': 74.0,
#   'happiestScore': 6.1739999999999995},
#  {'country': 'Libya',
#   'gdp_per_capita': 9446.0,
#   'co2_emissions': 57.583999999999996,
#   'population': 6871292.0,
#   'growthrate': 0.0138,
#   'countrysize': 1759540.0,
#   'pop_den': 4.0,
#   'happiestScore': 5.525},
#  {'country': 'India',
#   'gdp_per_capita': 9027.0,
#   'co2_emissions': 2454.774,
#   'population': 1380004385.0,
#   'growthrate': 0.009899999999999999,
#   'countrysize': 3287590.0,
#   'pop_den': 416.0,
#   'happiestScore': 4.015},
#  {'country': 'Guatemala',
#   'gdp_per_capita': 9009.0,
#   'co2_emissions': 17.76,
#   'population': 17915568.0,
#   'growthrate': 0.019,
#   'countrysize': 108889.0,
#   'pop_den': 161.0,
#   'happiestScore': 6.436},
#  {'country': 'Laos',
#   'gdp_per_capita': 8684.0,
#   'co2_emissions': 2.818,
#   'population': 7275560.0,
#   'growthrate': 0.0148,
#   'countrysize': 236800.0,
#   'pop_den': 30.0,
#   'happiestScore': 4.796},
#  {'country': 'Vietnam',
#   'gdp_per_capita': 8677.0,
#   'co2_emissions': 218.729,
#   'population': 97338579.0,
#   'growthrate': 0.0091,
#   'countrysize': 331212.0,
#   'pop_den': 291.0,
#   'happiestScore': 5.175},
#  {'country': 'El Salvador',
#   'gdp_per_capita': 8593.0,
#   'co2_emissions': 7.857,
#   'population': 6486205.0,
#   'growthrate': 0.0051,
#   'countrysize': 21041.0,
#   'pop_den': 307.0,
#   'happiestScore': 6.252999999999999},
#  {'country': 'Bolivia',
#   'gdp_per_capita': 8525.0,
#   'co2_emissions': 20.462,
#   'population': 11673021.0,
#   'growthrate': 0.0139,
#   'countrysize': 1098581.0,
#   'pop_den': 10.0,
#   'happiestScore': 5.779},
#  {'country': 'Moldova',
#   'gdp_per_capita': 8161.0,
#   'co2_emissions': 8.263,
#   'population': 4033963.0,
#   'growthrate': -0.0023,
#   'countrysize': 33846.0,
#   'pop_den': 119.0,
#   'happiestScore': 5.529},
#  {'country': 'Ghana',
#   'gdp_per_capita': 7343.0,
#   'co2_emissions': 18.625999999999998,
#   'population': 31072940.0,
#   'growthrate': 0.0215,
#   'countrysize': 238533.0,
#   'pop_den': 128.0,
#   'happiestScore': 4.996},
#  {'country': 'Myanmar',
#   'gdp_per_capita': 7220.0,
#   'co2_emissions': 28.462,
#   'population': 54409800.0,
#   'growthrate': 0.0067,
#   'countrysize': 676578.0,
#   'pop_den': 80.0,
#   'happiestScore': 4.36},
#  {'country': 'Nigeria',
#   'gdp_per_capita': 6172.0,
#   'co2_emissions': 94.84700000000001,
#   'population': 206139589.0,
#   'growthrate': 0.0258,
#   'countrysize': 923768.0,
#   'pop_den': 218.0,
#   'happiestScore': 5.265},
#  {'country': 'Pakistan',
#   'gdp_per_capita': 6016.0,
#   'co2_emissions': 197.297,
#   'population': 220892340.0,
#   'growthrate': 0.02,
#   'countrysize': 881912.0,
#   'pop_den': 246.0,
#   'happiestScore': 5.653},
#  {'country': 'Honduras',
#   'gdp_per_capita': 5600.0,
#   'co2_emissions': 10.562000000000001,
#   'population': 9904607.0,
#   'growthrate': 0.0163,
#   'countrysize': 112492.0,
#   'pop_den': 87.0,
#   'happiestScore': 5.86},
#  {'country': 'Bangladesh',
#   'gdp_per_capita': 5453.0,
#   'co2_emissions': 84.546,
#   'population': 164689383.0,
#   'growthrate': 0.0101,
#   'countrysize': 147570.0,
#   'pop_den': 1105.0,
#   'happiestScore': 4.456},
#  {'country': 'Nicaragua',
#   'gdp_per_capita': 5297.0,
#   'co2_emissions': 5.919,
#   'population': 6624554.0,
#   'growthrate': 0.0121,
#   'countrysize': 130373.0,
#   'pop_den': 50.0,
#   'happiestScore': 6.105},
#  {'country': 'Mauritania',
#   'gdp_per_capita': 5158.0,
#   'co2_emissions': 2.9619999999999997,
#   'population': 4649658.0,
#   'growthrate': 0.0274,
#   'countrysize': 1030700.0,
#   'pop_den': 4.0,
#   'happiestScore': 4.49},
#  {'country': 'Cambodia',
#   'gdp_per_capita': 5004.0,
#   'co2_emissions': 10.56,
#   'population': 16718965.0,
#   'growthrate': 0.0141,
#   'countrysize': 181035.0,
#   'pop_den': 91.0,
#   'happiestScore': 4.7},
#  {'country': 'Kyrgyzstan',
#   'gdp_per_capita': 4193.0,
#   'co2_emissions': 11.18,
#   'population': 6524195.0,
#   'growthrate': 0.0169,
#   'countrysize': 199951.0,
#   'pop_den': 32.0,
#   'happiestScore': 5.261},
#  {'country': 'Zambia',
#   'gdp_per_capita': 4174.0,
#   'co2_emissions': 4.967,
#   'population': 18383955.0,
#   'growthrate': 0.029300000000000003,
#   'countrysize': 752612.0,
#   'pop_den': 24.0,
#   'happiestScore': 4.107},
#  {'country': 'Cameroon',
#   'gdp_per_capita': 4099.0,
#   'co2_emissions': 9.767999999999999,
#   'population': 26545863.0,
#   'growthrate': 0.0259,
#   'countrysize': 475442.0,
#   'pop_den': 54.0,
#   'happiestScore': 5.044},
#  {'country': 'Senegal',
#   'gdp_per_capita': 4079.0,
#   'co2_emissions': 9.689,
#   'population': 16743927.0,
#   'growthrate': 0.0275,
#   'countrysize': 196722.0,
#   'pop_den': 83.0,
#   'happiestScore': 4.681},
#  {'country': 'Kenya',
#   'gdp_per_capita': 4078.0,
#   'co2_emissions': 18.594,
#   'population': 53771296.0,
#   'growthrate': 0.022799999999999997,
#   'countrysize': 580367.0,
#   'pop_den': 91.0,
#   'happiestScore': 4.5089999999999995},
#  {'country': 'Tajikistan',
#   'gdp_per_capita': 3751.0,
#   'co2_emissions': 5.699,
#   'population': 9537645.0,
#   'growthrate': 0.0232,
#   'countrysize': 143100.0,
#   'pop_den': 65.0,
#   'happiestScore': 5.4670000000000005},
#  {'country': 'Lesotho',
#   'gdp_per_capita': 3655.0,
#   'co2_emissions': 0.754,
#   'population': 2142249.0,
#   'growthrate': 0.008,
#   'countrysize': 30355.0,
#   'pop_den': 70.0,
#   'happiestScore': 3.802},
#  {'country': 'Tanzania',
#   'gdp_per_capita': 3652.0,
#   'co2_emissions': 14.65,
#   'population': 59734218.0,
#   'growthrate': 0.0298,
#   'countrysize': 945087.0,
#   'pop_den': 61.0,
#   'happiestScore': 3.2310000000000003},
#  {'country': 'Benin',
#   'gdp_per_capita': 3648.0,
#   'co2_emissions': 7.097,
#   'population': 12123200.0,
#   'growthrate': 0.0273,
#   'countrysize': 112622.0,
#   'pop_den': 105.0,
#   'happiestScore': 4.883},
#  {'country': 'Nepal',
#   'gdp_per_capita': 3550.0,
#   'co2_emissions': 8.218,
#   'population': 29136808.0,
#   'growthrate': 0.018500000000000003,
#   'countrysize': 147181.0,
#   'pop_den': 194.0,
#   'happiestScore': 4.913},
#  {'country': 'Comoros',
#   'gdp_per_capita': 2898.0,
#   'co2_emissions': 0.20600000000000002,
#   'population': 869601.0,
#   'growthrate': 0.022000000000000002,
#   'countrysize': 1862.0,
#   'pop_den': 457.0,
#   'happiestScore': 3.9730000000000003},
#  {'country': 'Zimbabwe',
#   'gdp_per_capita': 2778.0,
#   'co2_emissions': 12.087,
#   'population': 14862924.0,
#   'growthrate': 0.0148,
#   'countrysize': 390757.0,
#   'pop_den': 37.0,
#   'happiestScore': 3.6630000000000003},
#  {'country': 'Uganda',
#   'gdp_per_capita': 2753.0,
#   'co2_emissions': 5.042,
#   'population': 45741007.0,
#   'growthrate': 0.0332,
#   'countrysize': 241550.0,
#   'pop_den': 183.0,
#   'happiestScore': 4.189},
#  {'country': 'Ethiopia',
#   'gdp_per_capita': 2702.0,
#   'co2_emissions': 14.9,
#   'population': 114963588.0,
#   'growthrate': 0.025699999999999997,
#   'countrysize': 1104300.0,
#   'pop_den': 101.0,
#   'happiestScore': 4.2860000000000005},
#  {'country': 'Rwanda',
#   'gdp_per_capita': 2642.0,
#   'co2_emissions': 1.1059999999999999,
#   'population': 12952218.0,
#   'growthrate': 0.0258,
#   'countrysize': 26338.0,
#   'pop_den': 479.0,
#   'happiestScore': 3.3339999999999996},
#  {'country': 'Chad',
#   'gdp_per_capita': 2603.0,
#   'co2_emissions': 0.925,
#   'population': 16425864.0,
#   'growthrate': 0.03,
#   'countrysize': 1284000.0,
#   'pop_den': 12.0,
#   'happiestScore': 4.35},
#  {'country': 'Guinea',
#   'gdp_per_capita': 2574.0,
#   'co2_emissions': 2.7310000000000003,
#   'population': 13132795.0,
#   'growthrate': 0.028300000000000002,
#   'countrysize': 245857.0,
#   'pop_den': 52.0,
#   'happiestScore': 4.534},
#  {'country': 'Mali',
#   'gdp_per_capita': 2569.0,
#   'co2_emissions': 0.951,
#   'population': 20250833.0,
#   'growthrate': 0.0302,
#   'countrysize': 1240192.0,
#   'pop_den': 16.0,
#   'happiestScore': 4.39},
#  {'country': 'Yemen',
#   'gdp_per_capita': 2312.0,
#   'co2_emissions': 12.503,
#   'population': 29825964.0,
#   'growthrate': 0.022799999999999997,
#   'countrysize': 527968.0,
#   'pop_den': 55.0,
#   'happiestScore': 3.38},
#  {'country': 'Afghanistan',
#   'gdp_per_capita': 2182.0,
#   'co2_emissions': 11.422,
#   'population': 38928346.0,
#   'growthrate': 0.0233,
#   'countrysize': 652230.0,
#   'pop_den': 58.0,
#   'happiestScore': 3.2030000000000003},
#  {'country': 'Burkina Faso',
#   'gdp_per_capita': 2181.0,
#   'co2_emissions': 3.3989999999999996,
#   'population': 20903273.0,
#   'growthrate': 0.0286,
#   'countrysize': 272967.0,
#   'pop_den': 74.0,
#   'happiestScore': 4.587},
#  {'country': 'Haiti',
#   'gdp_per_capita': 1916.0,
#   'co2_emissions': 3.5210000000000004,
#   'population': 11402528.0,
#   'growthrate': 0.0124,
#   'countrysize': 27750.0,
#   'pop_den': 406.0,
#   'happiestScore': 3.597},
#  {'country': 'Togo',
#   'gdp_per_capita': 1913.0,
#   'co2_emissions': 2.843,
#   'population': 8278724.0,
#   'growthrate': 0.024300000000000002,
#   'countrysize': 56785.0,
#   'pop_den': 142.0,
#   'happiestScore': 4.085},
#  {'country': 'Madagascar',
#   'gdp_per_capita': 1776.0,
#   'co2_emissions': 4.156000000000001,
#   'population': 27691018.0,
#   'growthrate': 0.0268,
#   'countrysize': 587041.0,
#   'pop_den': 46.0,
#   'happiestScore': 3.9330000000000003},
#  {'country': 'Sierra Leone',
#   'gdp_per_capita': 1765.0,
#   'co2_emissions': 1.3090000000000002,
#   'population': 7976983.0,
#   'growthrate': 0.021,
#   'countrysize': 71740.0,
#   'pop_den': 109.0,
#   'happiestScore': 4.374},
#  {'country': 'Liberia',
#   'gdp_per_capita': 1428.0,
#   'co2_emissions': 1.129,
#   'population': 5057681.0,
#   'growthrate': 0.024399999999999998,
#   'countrysize': 111369.0,
#   'pop_den': 44.0,
#   'happiestScore': 3.975},
#  {'country': 'Mozambique',
#   'gdp_per_capita': 1372.0,
#   'co2_emissions': 7.754,
#   'population': 31255435.0,
#   'growthrate': 0.029300000000000003,
#   'countrysize': 801590.0,
#   'pop_den': 38.0,
#   'happiestScore': 4.466},
#  {'country': 'Malawi',
#   'gdp_per_capita': 1292.0,
#   'co2_emissions': 1.5719999999999998,
#   'population': 19129952.0,
#   'growthrate': 0.0269,
#   'countrysize': 118484.0,
#   'pop_den': 157.0,
#   'happiestScore': 3.41},
#  {'country': 'Niger',
#   'gdp_per_capita': 1152.0,
#   'co2_emissions': 2.497,
#   'population': 24206644.0,
#   'growthrate': 0.0384,
#   'countrysize': 1267000.0,
#   'pop_den': 18.0,
#   'happiestScore': 4.628},
#  {'country': 'Central African Republic',
#   'gdp_per_capita': 864.0,
#   'co2_emissions': 0.486,
#   'population': 4829767.0,
#   'growthrate': 0.0178,
#   'countrysize': 622984.0,
#   'pop_den': 8.0,
#   'happiestScore': 3.083},
#  {'country': 'Burundi',
#   'gdp_per_capita': 724.0,
#   'co2_emissions': 0.289,
#   'population': 11890784.0,
#   'growthrate': 0.031200000000000002,
#   'countrysize': 27834.0,
#   'pop_den': 414.0,
#   'happiestScore': 3.775}]

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
client = pymongo.MongoClient('mongodb://localhost:27017')
#define the database name
mydb = client["populcation_data_DB"]
#define the collection name
mycol = mydb["populcation_data"] 
mycol.insert_many(populcation_data_list)

# %%
# Out:
# Empty DataFrame
# Columns: [country, gdp_per_capita, co2_emissions, population, growthrate, countrysize, pop_den, happiestScore]
# Index: []
